# %% [markdown]
# # Data acquisition

# %%
import numpy as np
import pandas as pd
pd.options.display.max_rows = 10
np.set_printoptions(precision=4, suppress=True)

# %%
df = pd.read_csv("tran_sf_roadve.tsv",sep='\t')
df
# Out:
#     unit,vehicle,geo\time 2018  2017  2016  2015  2014  2013  2012  2011   \
# 0            NR,ANI_RD,BE    0     0     0     1     1     0     :     :
# 1            NR,ANI_RD,BG    6     5     6     5     3     5    12     7
# 2            NR,ANI_RD,DK    0     0     0     1     0     1     0     0
# 3            NR,ANI_RD,EE    0     :     :     :     :     :     :     :
# 4            NR,ANI_RD,HR    0     :     0     :     :     :     :     :
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 539        NR,VG_LE3P5,RO   73    64    63    77    67    61    72    64
# 540        NR,VG_LE3P5,SE   12     5     6    10     8     5    16    10
# 541        NR,VG_LE3P5,SI    0     0     0     0     0     5     5     1
# 542        NR,VG_LE3P5,SK    :     :     :     :     :     :     :     :
# 543        NR,VG_LE3P5,UK   38    41    51    34    34    39    34    35
#
#     2010   ... 2008  2007  2006  2005  2004  2003  2002  2001  2000  1999
# ...
